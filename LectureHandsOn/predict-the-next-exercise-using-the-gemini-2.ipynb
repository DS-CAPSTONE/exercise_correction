# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install -U google-generativeai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.0/165.0 kB 1.6 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.4/725.4 kB 8.7 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.6
#     Uninstalling google-ai-generativelanguage-0.6.6:
#       Successfully uninstalled google-ai-generativelanguage-0.6.6
#   Attempting uninstall: google-generativeai
#     Found existing installation: google-generativeai 0.7.2
#     Uninstalling google-generativeai-0.7.2:
#       Successfully uninstalled google-generativeai-0.7.2
# ...

# %%
import google.generativeai as genai
import os

genai.configure(api_key="AIzaSyAwd0YNF4FkBjPe2VaeXGbCgxk9DDpC60s")

# %%
import random
# Possible exercises and pain areas
exercises = ["squats", "push-ups", "deadlifts", "bench press", "lunges", "pull-ups", "planks", "squats", "push-ups", "deadlifts", "bench press", "lunges", "pull-ups", "planks", "squats", "push-ups", "deadlifts", "bench press", "lunges", "pull-ups", "planks", "squats", "push-ups", "deadlifts", "bench press", "lunges", "pull-ups", "planks"]
pain_areas = ["back", "shoulders", "knees", "elbows", "chest"]

# Function to generate a random exercise dictionary
def generate_random_exercise_history():
    exercise_count = random.randint(5, 15)  # Random total exercise count
    previous_exercises = {exercise: random.randint(5, 20) for exercise in random.sample(exercises, exercise_count)}
    paining_area = random.choice(pain_areas)  # Randomly choose a pain area
    return previous_exercises, paining_area

# Function to get exercise suggestion from the model
def get_exercise_suggestion(previous_exercises, paining_area):
    # Convert the dictionary to a string for the model input
    exercise_history = ", ".join([f"{count} {exercise}" for exercise, count in previous_exercises.items()])
    response = model.generate_content(f"Based on these exercises and counts: {exercise_history}, and the pain area: {paining_area}, suggest the next exercise in one word.")
    return response.text.strip()

# Run multiple predictions
for _ in range(10):  # Change the range for more predictions
    previous_exercises, paining_area = generate_random_exercise_history()
    suggestion = get_exercise_suggestion(previous_exercises, paining_area)
    print(f"Exercises: {previous_exercises}, Pain Area: {paining_area}, Suggested Exercise: {suggestion}")
# Out:
# Exercises: {'squats': 14, 'bench press': 8, 'planks': 8, 'lunges': 15, 'pull-ups': 6, 'push-ups': 12, 'deadlifts': 5}, Pain Area: back, Suggested Exercise: **Rows**
# Exercises: {'planks': 17, 'pull-ups': 8, 'bench press': 14, 'push-ups': 18, 'squats': 11}, Pain Area: back, Suggested Exercise: **Deadlifts**
# Exercises: {'squats': 10, 'planks': 8, 'lunges': 8, 'deadlifts': 18, 'push-ups': 7, 'bench press': 17, 'pull-ups': 17}, Pain Area: chest, Suggested Exercise: **Biceps**
# Exercises: {'squats': 6, 'pull-ups': 9, 'push-ups': 7, 'bench press': 14, 'lunges': 14, 'planks': 13}, Pain Area: chest, Suggested Exercise: **Rows**
# Exercises: {'bench press': 20, 'deadlifts': 11, 'pull-ups': 12, 'push-ups': 13, 'planks': 20, 'lunges': 18}, Pain Area: back, Suggested Exercise: Stretching
# Exercises: {'planks': 5, 'squats': 19, 'deadlifts': 18, 'lunges': 5, 'pull-ups': 15}, Pain Area: knees, Suggested Exercise: Biceps
# ...
